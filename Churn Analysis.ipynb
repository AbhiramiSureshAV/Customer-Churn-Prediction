# %%
#Import the neccessary libraries

import pandas as pd
import numpy as np
import sklearn
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score

# %%
#load and read the dataset

df=pd.read_csv('churn.csv')
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
#To display the total number of rows and columns

df.shape
# Out:
# (7043, 21)

# %%
#To display columns

df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
#To find the missing or null values

df.isnull()
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0          False   False          False    False       False   False
# 1          False   False          False    False       False   False
# 2          False   False          False    False       False   False
# 3          False   False          False    False       False   False
# 4          False   False          False    False       False   False
# ...          ...     ...            ...      ...         ...     ...
# 7038       False   False          False    False       False   False
# 7039       False   False          False    False       False   False
# 7040       False   False          False    False       False   False
# 7041       False   False          False    False       False   False
# 7042       False   False          False    False       False   False
#
#       PhoneService  MultipleLines  InternetService  OnlineSecurity  ...  \
# ...

# %%
#To find the number of missing or null values in each columns

df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %% [markdown]
# There are no null values in this dataset

# %%
#To display the Statistics of this dataset

df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
#To display the customer churn

df['Churn'].value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
#To display the datatypes of each columns

df.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %% [markdown]
# ## TO VISUALISE THE COUNT OF CUSTOMER CHURN

# %%
#First convert to categorical

df['Churn'] = df['Churn'].astype('category')

# %%
df['Churn']
# Out:
# 0        No
# 1        No
# 2       Yes
# 3        No
# 4       Yes
#        ...
# 7038     No
# 7039     No
# 7040     No
# 7041    Yes
# 7042     No
# Name: Churn, Length: 7043, dtype: category
# Categories (2, object): ['No', 'Yes']

# %%
#plot

churn_counts = df['Churn'].value_counts()
c={'red','green'}
plt.bar(churn_counts.index, churn_counts.values,color=c)
plt.title('Churn Count')
plt.xlabel('Churn')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ## PERCENTAGE OF CUSTOMERS LEAVING

# %%
#No of customers stayed 

stayed=df[df.Churn=='No'].shape[0]
stayed
# Out:
# 5174

# %%
#No of customers churned

churned=df[df.Churn=='Yes'].shape[0]
churned
# Out:
# 1869

# %%
#Calculate percentage of customers stayed 

print((stayed/(stayed+churned))*100,'% of customers stayed in the company')
# Out:
# 73.4630129206304 % of customers stayed in the company

# %%
#Calculate percentage of customers left 

print((churned/(stayed+churned))*100,'% of customers left the company')
# Out:
# 26.536987079369588 % of customers left the company

# %% [markdown]
# ## VISUALISING THE CHURN COUNT

# %%
sns.countplot(x='gender',hue='Churn',data=df)
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %%
#You can visualise your own graphs to get more inferences and conclusions from the dataset to predict model

sns.countplot(x='Dependents',hue='Churn',data=df)
# Out:
# <Axes: xlabel='Dependents', ylabel='count'>

# %% [markdown]
# ## CLEAN DATASET

# %%
#Clean Dataset (remove unnecessary features)
#Here we remove the customer ID column because it doesnt contribute towards the churn prediction

df=df.drop('customerID',axis=1)

# %%
df
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0     Female              0     Yes         No       1           No
# 1       Male              0      No         No      34          Yes
# 2       Male              0      No         No       2          Yes
# 3       Male              0      No         No      45           No
# 4     Female              0      No         No       2          Yes
# ...      ...            ...     ...        ...     ...          ...
# 7038    Male              0     Yes        Yes      24          Yes
# 7039  Female              0     Yes        Yes      72          Yes
# 7040  Female              0     Yes        Yes      11           No
# 7041    Male              1     Yes         No       4          Yes
# 7042    Male              0      No         No      66          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0     No phone service             DSL             No          Yes
# ...

# %% [markdown]
# ## CONVERSION OF NON-NUMERIC TO NUMERIC(CATEGORICAL)

# %%
for column in df.columns:
    if df[column].dtype==np.number:
        continue
    else:
        df[column]=LabelEncoder().fit_transform(df[column])
# Out:
# C:\Users\hp pc\AppData\Local\Temp\ipykernel_19764\1000450455.py:2: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if df[column].dtype==np.number:
# C:\Users\hp pc\AppData\Local\Temp\ipykernel_19764\1000450455.py:2: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if df[column].dtype==np.number:
# C:\Users\hp pc\AppData\Local\Temp\ipykernel_19764\1000450455.py:2: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if df[column].dtype==np.number:
# C:\Users\hp pc\AppData\Local\Temp\ipykernel_19764\1000450455.py:2: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
# ...

# %%
df.dtypes
# Out:
# gender                int32
# SeniorCitizen         int64
# Partner               int32
# Dependents            int32
# tenure                int64
# PhoneService          int32
# MultipleLines         int32
# InternetService       int32
# OnlineSecurity        int32
# OnlineBackup          int32
# DeviceProtection      int32
# TechSupport           int32
# StreamingTV           int32
# StreamingMovies       int32
# Contract              int32
# PaperlessBilling      int32
# PaymentMethod         int32
# MonthlyCharges      float64
# TotalCharges          int32
# Churn                 int32
# dtype: object

# %%
#To didplay the converted dataset

df.head()
# Out:
#    gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0       0              0        1           0       1             0
# 1       1              0        0           0      34             1
# 2       1              0        0           0       2             1
# 3       1              0        0           0      45             0
# 4       0              0        0           0       2             1
#
#    MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# 0              1                0               0             2
# 1              0                0               2             0
# 2              0                0               2             2
# 3              1                0               2             0
# 4              0                1               0             0
#
#    DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# 0                 0            0            0                0         0
# ...

# %% [markdown]
# ## SCALE THE DATA

# %%
x=df.drop('Churn',axis=1)
y=df['Churn']
x=StandardScaler().fit_transform(x)

# %% [markdown]
# ## SPLITTING THE DATA INTO TRAINING AND TESTING (HERE 80-20)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=34)

# %% [markdown]
# ## MODEL CREATION AND TRAINING

# %% [markdown]
# # LOGISTIC REGRESSION

# %%
model=LogisticRegression()

model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# ## PREDICTIONS

# %%
predictions=model.predict(x_test)
print(predictions)
# Out:
# [0 0 0 ... 0 0 0]

# %%
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.88      0.85      1023
#            1       0.62      0.51      0.56       386
#
#     accuracy                           0.78      1409
#    macro avg       0.73      0.70      0.71      1409
# weighted avg       0.77      0.78      0.77      1409

# %% [markdown]
# # DECISION TREE

# %%
dt=DecisionTreeClassifier(random_state=1)

# %%
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(random_state=1)

# %%
dt_pred=dt.predict(x_test)
dt_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
accuracy_score(y_test,dt_pred)
# Out:
# 0.7175301632363378

# %%
#Other classification models also could be tried and based the metrics the best model could be chosen
